# %%
# Step 1 read the file 'gapminder_total_fertility.csv' into pandas.
import pandas as pd
fert=pd.read_csv('\\Users\\X1\\Documents\\spiced_projects\\fenugreek-student-code\\week1\\data\\gapminder_total_fertility.csv',index_col=0)
fert.head()
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %%
# Step 2 read the file 'gapminder_lifeexpectancy.xlsx' into pandas.
life=pd.read_excel('\\Users\\X1\\Documents\\spiced_projects\\fenugreek-student-code\\week1\\data\\gapminder_lifeexpectancy.xlsx',index_col=0)
life.head()
# Out:
#                        1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  1806.0  \
# Life expectancy
# Abkhazia                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Afghanistan             28.21   28.20   28.19   28.18   28.17   28.16   28.15
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40   35.40   35.40   35.40   35.40
# Algeria                 28.82   28.82   28.82   28.82   28.82   28.82   28.82
#
#                        1807.0  1808.0  1809.0  ...  2007.0  2008.0  2009.0  \
# Life expectancy                                ...
# Abkhazia                  NaN     NaN     NaN  ...     NaN     NaN     NaN
# Afghanistan             28.14   28.13   28.12  ...    52.4    52.8    53.3
# Akrotiri and Dhekelia     NaN     NaN     NaN  ...     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40  ...    76.6    76.8    77.0
# ...

# %%
# Step 3 check the shape of both tables
fert.shape
# Out:
# (260, 216)

# %%
life.shape
# Out:
# (260, 217)

# %%
# Step 4 Take a look at the columns of both tables
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Float64Index([1800.0, 1801.0, 1802.0, 1803.0, 1804.0, 1805.0, 1806.0, 1807.0,
#               1808.0, 1809.0,
#               ...
#               2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0,
#               2015.0, 2016.0],
#              dtype='float64', length=217)

# %%
# To merge the tables, we need to convert both into the same format (int):
fert.columns = fert.columns.astype(int)
life.columns=life.columns.astype(int)

# %%
fert.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
# Step 5 check the row index of the table
fert.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'Åland'],
#       dtype='object', name='Total fertility rate', length=260)

# %%
# the name of the index should be called country. change the name of the index
fert.index.name='country'

# %%
# Step 6 convert the tables into long format. First, we have to move the row index into a column
fert.reset_index(inplace=True)

# %%
#we use the convenient melt function for the conversion
fert= fert.melt(id_vars='country', var_name='year', value_name='fertility_rate',ignore_index=True)
fert.head()
# Out:
#                  country  year  fertility_rate
# 0               Abkhazia  1800             NaN
# 1            Afghanistan  1800            7.00
# 2  Akrotiri and Dhekelia  1800             NaN
# 3                Albania  1800            4.60
# 4                Algeria  1800            6.99

# %%
#Step 7 Repeat steps 5-6 for the life expectancy data, so that it’s also in long format.
life.index
life.index.name='country'

# %%
life.reset_index(inplace=True)

# %%
life=life.melt(id_vars='country', var_name='year', value_name='life_expectancy', ignore_index=True)
life.head()
# Out:
#                  country  year  life_expectancy
# 0               Abkhazia  1800              NaN
# 1            Afghanistan  1800            28.21
# 2  Akrotiri and Dhekelia  1800              NaN
# 3                Albania  1800            35.40
# 4                Algeria  1800            28.82

# %%
# Step 8 read the file 'gapminder_population.xlsx' into pandas.
pop=pd.read_excel('\\Users\\X1\\Documents\\spiced_projects\\fenugreek-student-code\\week1\\data\\gapminder_population.xlsx', index_col=0)
pop.head()
# Out:
#                           1800.0     1810.0     1820.0     1830.0     1840.0  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                           1850.0     1860.0     1870.0     1880.0     1890.0  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
# ...

# %%
# check the shape of both tables
pop.shape
# Out:
# (275, 81)

# %%
# Take a look at the columns of table
pop.columns
# Out:
# Float64Index([1800.0, 1810.0, 1820.0, 1830.0, 1840.0, 1850.0, 1860.0, 1870.0,
#               1880.0, 1890.0, 1900.0, 1910.0, 1920.0, 1930.0, 1940.0, 1950.0,
#               1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0, 1958.0,
#               1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0,
#               1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0,
#               1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0,
#               1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0,
#               1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0,
#               1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0,
#               2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0,
#               2015.0],
#              dtype='float64')

# %%
# To merge the tables, we need to convert both into the same format (int):
pop.columns.astype(int)
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %%
# check the row index of the table
pop.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'British Indian Ocean Territory', 'Clipperton',
#        'French Southern and Antarctic Lands', 'Gaza Strip',
#        'Heard and McDonald Islands', 'Northern Marianas',
#        'South Georgia and the South Sandwich Islands',
#        'US Minor Outlying Islands', 'Virgin Islands', 'West Bank'],
#       dtype='object', name='Total population', length=275)

# %%
# the name of the index should be called country. change the name of the index
pop.index.name='country'

# %%
# convert the table into long format. First, we have to move the row index into a column
pop.reset_index(inplace=True)

# %%
# we use the convenient melt function for the conversion
pop=pop.melt(id_vars='country', var_name='year', value_name='population')
pop.head()
# Out:
#                  country    year  population
# 0               Abkhazia  1800.0         NaN
# 1            Afghanistan  1800.0   3280000.0
# 2  Akrotiri and Dhekelia  1800.0         NaN
# 3                Albania  1800.0    410445.0
# 4                Algeria  1800.0   2503218.0

# %%
#  read the file 'continents.csv' into pandas.
cont=pd.read_csv('\\Users\\X1\\Documents\\spiced_projects\\fenugreek-student-code\\week1\\data\\continents.csv',sep=';', index_col=0)
cont.head()
# Out:
#             country
# continent
# Africa      Algeria
# Africa       Angola
# Africa        Benin
# Africa     Botswana
# Africa      Burkina

# %%
# check the shape of both tables
cont.shape
# Out:
# (194, 1)

# %%
# convert the table into long format. First, we have to move the row index into a column
cont.reset_index(inplace=True)

# %%
# we use the convenient melt function for the conversion
cont=cont.melt(id_vars='country', value_name='continent')
cont.head()
# Out:
# C:\Users\X1\AppData\Local\Temp/ipykernel_28060/1297889986.py:2: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   cont=cont.melt(id_vars='country', value_name='continent')
#     country   variable continent
# 0   Algeria  continent    Africa
# 1    Angola  continent    Africa
# 2     Benin  continent    Africa
# 3  Botswana  continent    Africa
# 4   Burkina  continent    Africa

# %%
# we can start gluing the DataFrames together
#first of all, we merge fert and pop to get df_1
df_1=fert.merge(pop, how='inner', on=['country','year'])
df_1
# Out:
#                      country  year  fertility_rate  population
# 0                   Abkhazia  1800             NaN         NaN
# 1                Afghanistan  1800            7.00   3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN         NaN
# 3                    Albania  1800            4.60    410445.0
# 4                    Algeria  1800            6.99   2503218.0
# ...                      ...   ...             ...         ...
# 20974             Yugoslavia  2015             NaN         NaN
# 20975                 Zambia  2015            5.59  16211767.0
# 20976               Zimbabwe  2015            3.35  15602751.0
# 20977                  Åland  2015             NaN         NaN
# 20978                  Åland  2015             NaN         NaN
#
# [20979 rows x 4 columns]

# %%
#now we merge population to df_1 table
df_2=df_1.merge(life, how='inner', on=['country', 'year'])
df_2
# Out:
#                      country  year  fertility_rate  population  \
# 0                   Abkhazia  1800             NaN         NaN
# 1                Afghanistan  1800            7.00   3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN         NaN
# 3                    Albania  1800            4.60    410445.0
# 4                    Algeria  1800            6.99   2503218.0
# ...                      ...   ...             ...         ...
# 20974             Yugoslavia  2015             NaN         NaN
# 20975                 Zambia  2015            5.59  16211767.0
# 20976               Zimbabwe  2015            3.35  15602751.0
# 20977                  Åland  2015             NaN         NaN
# 20978                  Åland  2015             NaN         NaN
#
#        life_expectancy
# 0                  NaN
# 1                28.21
# 2                  NaN
# 3                35.40
# 4                28.82
# ...                ...
# 20974              NaN
# ...

# %%
#then we merge continent to df_2 table
df=df_2.merge(cont, how='inner', on='country')
df.drop('variable', axis=1, inplace=True)
df
# Out:
#            country  year  fertility_rate  population  life_expectancy  \
# 0      Afghanistan  1800            7.00   3280000.0            28.21
# 1      Afghanistan  1810            7.00   3280000.0            28.11
# 2      Afghanistan  1820            7.00   3323519.0            28.01
# 3      Afghanistan  1830            7.00   3448982.0            27.90
# 4      Afghanistan  1840            7.00   3625022.0            27.80
# ...            ...   ...             ...         ...              ...
# 14170     Zimbabwe  2011            3.64  14255592.0            51.60
# 14171     Zimbabwe  2012            3.56  14565482.0            54.20
# 14172     Zimbabwe  2013            3.49  14898092.0            55.70
# 14173     Zimbabwe  2014            3.41  15245855.0            57.00
# 14174     Zimbabwe  2015            3.35  15602751.0            59.30
#
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4          Asia
# ...         ...
# ...

# %%
df.dropna(inplace=True)

# %%
# Step 10 With all the data merged into a single object, you can now select specific columns and plot them
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="dark")
plt.style.use('dark_background')
plt.figure(figsize=(8,5))
df_subset = df.loc[df['year'] == 2000]
sns.scatterplot(x='life_expectancy', y='fertility_rate',data=df_subset, alpha=0.5,hue='continent',legend=False)


plt.axis((0,100,0,15))
plt.title('Correlation between fertility and life expectancy')
plt.xlabel('Life Expectancy')
plt.ylabel('Fertility')
    
sns.despine()

# %%
# Step 12 Add another dimension to the visualization by utilizing the population data.
#Adjust the plot, so that the size of the symbols represent the population from the gapminder dataset.
 
for i in range(1960,2016):
    sns.set_theme(style="dark")
    plt.style.use('dark_background')
    plt.figure(figsize=(8,5))
    df_subset = df.loc[df['year'] == i]
    sns.scatterplot(x='life_expectancy', y='fertility_rate',size=df_subset['population']//100_000, legend=False, hue='continent',
            data=df_subset, alpha=0.5)
    
    fname='lifeexp_'+str(i)+'.png'
    
    plt.axis((0,100,0,15))
    plt.title(f'Correlation between fertility and life expectancy-{i}')
    plt.xlabel('Life Expectancy')
    plt.ylabel('Fertility')
    
    sns.despine()
    plt.savefig(fname, dpi=90)
    plt.close()

# %%
# Step 11 To create an animated scatterplot showing the correlation between life expectancy and fertility, create one plot for each year between 1960 and 2015
for i in range(1960,2016):
   
    sns.set_theme(style="dark")
    plt.style.use('dark_background')
    plt.figure(figsize=(8,5))
    df_subset = df.loc[df['year'] == i]
    sns.scatterplot(x='life_expectancy', y='fertility_rate',hue='continent', legend=False,
            data=df_subset, alpha=0.5)
    
    fname='lifeexp_'+str(i)+'.png'
    
    plt.axis((0,100,0,15))
    plt.title(f'Correlation between fertility and life expectancy-{i}')
    plt.xlabel('Life Expectancy')
    plt.ylabel('Fertility')
    
    sns.despine()
    plt.savefig(fname, dpi=90)
    plt.close()

# %%
# Step 13 Install the Python module imageio, by typing in the terminal
pip install imageio
# Out:
#   File "C:\Users\X1\AppData\Local\Temp/ipykernel_28060/3489995413.py", line 2
#     pip install imageio
#         ^
# SyntaxError: invalid syntax

# %%
# generate a gif file from the individual pictures, adjust the following code example and execute it
import imageio

images = []

for i in range(1960, 2016):
    filename = 'lifeexp_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('gapminder.gif', images, fps=5)
